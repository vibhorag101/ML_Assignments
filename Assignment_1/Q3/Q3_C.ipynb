# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# %%
reader=pd.read_excel('Dry_Bean_Dataset.xlsx')
df=pd.DataFrame(reader)

# %%
df1=df.drop(["Class"],axis=1)
tempClass=df["Class"]

# %%
tsne=TSNE(random_state=2,perplexity=30,n_iter=1000)
res=tsne.fit_transform(df1)
res=np.vstack((res.T,tempClass))
res=res.T
# Out:
# c:\Users\Vibhor\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\Vibhor\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
dfTsne=pd.DataFrame(data=res,columns=("Dim_1","Dim_2","Class"))
sns.scatterplot(data=dfTsne,x="Dim_1",y="Dim_2",hue="Class",palette='deep',style = 'Class',legend='full')
plt.show()
